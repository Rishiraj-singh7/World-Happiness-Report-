# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] = '#FFE5B4'

# %%
data = pd.read_csv('happy.csv')

# %%
data.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
#  Data Manipulation

# %%
type(data)#Check the type of variable worl
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape#Number of rows and columns in our dataset
# Out:
# (149, 20)

# %%
data.info()#Info about the column names, their data types and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
data.describe()#Summary Statistics
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
data.isnull().sum() #missing or null value
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
data.dtypes
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
data_columns = ['Country name','Regional indicator', 'Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# %%
data = data[data_columns].copy()

# %%
happy_df = data.rename({'Country name': 'country_name','Regional indicator': 'regional_indicator', 'Ladder score': 'ladder_score', 'Logged GDP per capita': 'logged_gdp_per_capita', 'Social support':'social_support','Healthy life expectancy':'healthy_life_expectancy', 'Freedom to make life choices':'freedom_to_make_choices','Generosity':'generosity','Perceptions of corruption':'prerception_of_corruption'}, axis = 1)

# %%
happy_df.head(4)
# Out:
#   country_name regional_indicator  ladder_score  logged_gdp_per_capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
#
#    social_support  healthy_life_expectancy  freedom_to_make_choices  \
# 0           0.954                     72.0                    0.949
# 1           0.954                     72.7                    0.946
# 2           0.942                     74.4                    0.919
# 3           0.983                     73.0                    0.955
#
#    generosity  prerception_of_corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179
# 2       0.025                      0.292
# 3       0.160                      0.673

# %%
happy_df.isnull().sum()
# Out:
# country_name                 0
# regional_indicator           0
# ladder_score                 0
# logged_gdp_per_capita        0
# social_support               0
# healthy_life_expectancy      0
# freedom_to_make_choices      0
# generosity                   0
# prerception_of_corruption    0
# dtype: int64

# %%
#plt btw hapiness and gdp
plt.rcParams['figure.figsize'] = (15,7)
plt.title('Plot bwtween hapiness Score and GDP')
sns.scatterplot(x=happy_df.ladder_score , y = happy_df.logged_gdp_per_capita, hue= happy_df.regional_indicator, s =200 );
plt.legend(loc ='upper left', fontsize = '10')
plt.xlabel('Hapiness score')
plt.ylabel('Gdp per capta')
# Out:
# Text(0, 0.5, 'Gdp per capta')

# %%
gdp_region = happy_df.groupby('regional_indicator')['logged_gdp_per_capita'].sum()
gdp_region
# Out:
# regional_indicator
# Central and Eastern Europe            171.854
# Commonwealth of Independent States    112.822
# East Asia                              62.206
# Latin America and Caribbean           187.400
# Middle East and North Africa          164.324
# North America and ANZ                  43.238
# South Asia                             60.778
# Southeast Asia                         84.793
# Sub-Saharan Africa                    290.707
# Western Europe                        227.277
# Name: logged_gdp_per_capita, dtype: float64

# %%
gdp_region.plot.pie(autopct = '%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
#total no of country in each region

total_country = happy_df.groupby('regional_indicator')[['country_name']].count()
total_country
# Out:
#                                     country_name
# regional_indicator
# Central and Eastern Europe                    17
# Commonwealth of Independent States            12
# East Asia                                      6
# Latin America and Caribbean                   20
# Middle East and North Africa                  17
# North America and ANZ                          4
# South Asia                                     7
# Southeast Asia                                 9
# Sub-Saharan Africa                            36
# Western Europe                                21

# %%
#correlation map

cor = happy_df.corr(method= "pearson")
f, ax = plt.subplots(figsize= (12,6)) 
sns.heatmap(cor, mask = np.zeros_like(cor, dtype=np.bool),
            cmap="Blues", square=True, ax=ax)
# Out:
# /tmp/ipykernel_6436/34498764.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(cor, mask = np.zeros_like(cor, dtype=np.bool),
# <AxesSubplot:>

# %%
# corruption in regions
corruption = happy_df.groupby('regional_indicator')[['prerception_of_corruption']].mean()
corruption
# Out:
#                                     prerception_of_corruption
# regional_indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
plt.rcParams['figure.figsize'] = (12,8)
plt.title('Perception of Corruption in various regions')
plt.xlabel('Regions', fontsize = 15)
plt.ylabel('corruption index', fontsize = 15)
plt.xticks(rotation = 30, ha='right')
plt.bar(corruption.index, corruption.prerception_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
# life expectancy (top 10,low 10)
top_10 = happy_df.head(10)
bottom_10 = happy_df.tail(10)

# %%
gif, axes= plt.subplots(1,2, figsize= (16,6))
plt.tight_layout(pad=2)
xlabls= top_10.country_name
axes[0].set_title('Top 10 happiest countries life expectancy')
axes[0].set_xticklabels(xlabls, rotation= 45,ha='right')
sns.barplot(x= top_10.country_name, y= top_10.healthy_life_expectancy, ax= axes[0])
axes[0].set_xlabel('Country Names')
axes[0].set_ylabel('Life expectancy')


xlabls= bottom_10.country_name
axes[1].set_title('bottom 10 least countries life expectancy')
axes[1].set_xticklabels(xlabls, rotation= 45,ha='right')
sns.barplot(x= bottom_10.country_name, y= bottom_10.healthy_life_expectancy, ax= axes[1])
axes[1].set_xlabel('Country Names')
axes[1].set_ylabel('Life expectancy')
# Out:
# /tmp/ipykernel_6436/530249574.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(xlabls, rotation= 45,ha='right')
# /tmp/ipykernel_6436/530249574.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(xlabls, rotation= 45,ha='right')
# Text(599.1068181818181, 0.5, 'Life expectancy')

# %%
happy_df.head(2)
# Out:
#   country_name regional_indicator  ladder_score  logged_gdp_per_capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
#
#    social_support  healthy_life_expectancy  freedom_to_make_choices  \
# 0           0.954                     72.0                    0.949
# 1           0.954                     72.7                    0.946
#
#    generosity  prerception_of_corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179

# %%
# scatter plot
plt.rcParams['figure.figsize'] = (15,7)
sns.scatterplot(x=happy_df.freedom_to_make_choices, y=happy_df.ladder_score, hue=happy_df.regional_indicator, s =200)
plt.legend(loc = 'upper left', fontsize = '12')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness score')
# Out:
# Text(0, 0.5, 'Happiness score')

# %%
# most corrupt countries
M_country = happy_df.sort_values(by='prerception_of_corruption').head(10)

plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries with most corrption')
plt.xlabel('country', fontsize= 13)
plt.ylabel('corruption index', fontsize = 13)
plt.xticks(rotation= 30 , ha= 'right')
plt.bar(M_country.country_name, M_country.prerception_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
# least corrupt countries
M_country = happy_df.sort_values(by='prerception_of_corruption').tail(10)

plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries with least corrption')
plt.xlabel('country', fontsize= 13)
plt.ylabel('corruption index', fontsize = 13)
plt.xticks(rotation= 30 , ha= 'right')
plt.bar(M_country.country_name, M_country.prerception_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
happy_df.head(1)
# Out:
#   country_name regional_indicator  ladder_score  logged_gdp_per_capita  \
# 0      Finland     Western Europe         7.842                 10.775
#
#    social_support  healthy_life_expectancy  freedom_to_make_choices  \
# 0           0.954                     72.0                    0.949
#
#    generosity  prerception_of_corruption
# 0      -0.098                      0.186

# %%
# corruption vs happiness (corruption various with happiness)
plt.rcParams['figure.figsize'] =(15,7)
sns.scatterplot(x =happy_df.ladder_score, y=happy_df.prerception_of_corruption, hue=happy_df.regional_indicator, s=200)
plt.legend(loc='lower left', fontsize ='14')
plt.xlabel('happiness score')
plt.ylabel('corruption')
# Out:
# Text(0, 0.5, 'corruption')
